# %% [markdown]
# # Campaign Winner Predictor Results and OFFICIAL RESULTS USA and Ecuador Study by Gerardo Bonnard

# %%
from IPython.display import display, HTML

html_content = """
<h1>Introduction</h1>
<p>This document presents an analysis of the hypothesis that electoral fraud may have occurred in Ecuador, drawing comparisons with the recent U.S. elections given the similarities in social media use between the 2 countries.</p>

<h3>Methodology</h3>
<p>By examining predictive models alongside official results, we aim to identify discrepancies that could suggest irregularities in the electoral process.</p>

<h3>Findings</h3>
<p>The findings highlight the accuracy of the U.S. electoral predictions while raising concerns about the integrity of the electoral results in Ecuador.</p>

<h3>Social Media Analysis</h3>
<p>At the same time, we aim to uncover a more efficient and economic way to predict political outcomes via social media interactions.</p>
"""

display(HTML(html_content))
# Out:
# <h1>Introduction</h1>
# <p>This document presents an analysis of the hypothesis that electoral fraud may have occurred in Ecuador, drawing comparisons with the recent U.S. elections given the similarities in social media use between the 2 countries.</p>
#
# <h3>Methodology</h3>
# <p>By examining predictive models alongside official results, we aim to identify discrepancies that could suggest irregularities in the electoral process.</p>
#
# <h3>Findings</h3>
# <p>The findings highlight the accuracy of the U.S. electoral predictions while raising concerns about the integrity of the electoral results in Ecuador.</p>
#
# <h3>Social Media Analysis</h3>
# <p>At the same time, we aim to uncover a more efficient and economic way to predict political outcomes via social media interactions.</p>

# %% [markdown]
# # USA

# %%
import matplotlib.pyplot as plt

# Data from your results
candidates = ['Donald J Trump', 'Kamala Harris']
percentages = [57.39, 42.61]  # Percentages

# Create a vertical bar chart
plt.bar(candidates, percentages, color=['red', 'blue'])

# Add title and labels
plt.title('USA Campaing winner predictor results')
plt.xlabel('Candidates')
plt.ylabel('Percentage (%)')

# Set y-axis limits for better visualization
plt.ylim(0, 100)

# Show the chart
plt.show()

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': ['Donald J Trump', 'Kamala Harris'],
    'Percentage (%)': [57.39, 42.61]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## USA Campaing winner predictor results"))

# Display the DataFrame
display(df)
# Out:
# ## USA Campaing winner predictor results
#         Candidate  Percentage (%)
# 0  Donald J Trump           57.39
# 1   Kamala Harris           42.61

# %%
import matplotlib.pyplot as plt

# Data from your results
candidates = ['Donald J Trump', 'Kamala Harris']
percentages = [57.94, 42.06]  # Percentages

# Create a vertical bar chart
plt.bar(candidates, percentages, color=['red', 'blue'])

# Add title and labels
plt.title('USA Official results')
plt.xlabel('Candidates')
plt.ylabel('Percentage (%)')

# Set y-axis limits for better visualization
plt.ylim(0, 100)

# Show the chart
plt.show()

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': ['Donald J Trump', 'Kamala Harris'],
    'Percentage (%)': [57.94, 42.06]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## USA official results"))

# Display the DataFrame
display(df)
# Out:
# ## USA official results
#         Candidate  Percentage (%)
# 0  Donald J Trump           57.94
# 1   Kamala Harris           42.06

# %% [markdown]
# ## Chi-square test USA

# %%
import numpy as np
from scipy.stats import chisquare

# Observed frequencies (official results)
observed = np.array([57.94, 42.06])

# Expected frequencies (predicted results)
expected = np.array([57.39, 42.61])

# Perform the chi-square test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Output the results
print(f"Chi-square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")

# Determine significance
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The discrepancies are statistically significant.")
else:
    print("Fail to reject the null hypothesis: The discrepancies are not statistically significant.")
# Out:
# Chi-square Statistic: 0.012370225598973352
# P-value: 0.9114406902627683
# Fail to reject the null hypothesis: The discrepancies are not statistically significant.

# %% [markdown]
# # Predictive stats compare to Official results USA study

# %%
# Predictive stats compare to Official results
# Differences and accuracy

# Official and predicted results
official_results = {
    "Donald J. Trump": 57.94,
    "Kamala Harris": 42.06
}

predicted_results = {
    "Donald J. Trump": 57.39,
    "Kamala Harris": 42.61
}

# Calculate differences
differences = {}
for candidate in official_results:
    differences[candidate] = abs(predicted_results[candidate] - official_results[candidate])

# Print results
for candidate in official_results:
    official = official_results[candidate]
    predicted = predicted_results[candidate]
    difference = differences[candidate]
    
    if predicted > official:
        sign = "+"
    else:
        sign = "-"
    
    print(f"{candidate}:")
    print(f"  Official Percentage: {official:.2f}%")
    print(f"  Predicted Percentage: {predicted:.2f}%")
    print(f"  Difference = {sign}{difference:.2f}%")
    print()
# Out:
# Donald J. Trump:
#   Official Percentage: 57.94%
#   Predicted Percentage: 57.39%
#   Difference = -0.55%
#
# Kamala Harris:
#   Official Percentage: 42.06%
#   Predicted Percentage: 42.61%
#   Difference = +0.55%

# %% [markdown]
# # Predictive Stats Compared to Official Results
#
# ## Differences and Accuracy
#
# ### Donald J. Trump:
# - **Official Percentage:** 57.94%
# - **Predicted Percentage:** 57.39%
# - **Difference:** -0.55%
#
# ### Kamala Harris:
# - **Official Percentage:** 42.06%
# - **Predicted Percentage:** 42.61%
# - **Difference:** +0.55%
#
#   ## Accuracy Campaing Winner predictor Percentage
#  # **98.90%**

# %% [markdown]
# # USA Comparisson of Official Results and Predicted Results / Bar Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Donald J. Trump', 'Kamala Harris']

# Official Results
official_results = [57.94, 42.06]

# Predicted Results
predicted_results = [57.39, 42.61]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Official Results and Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.show()

# %% [markdown]
# # USA Comparisson of Official Results and Predicted Results / Scatter Plot

# %%
import matplotlib.pyplot as plt

# Candidates
candidates = ['Donald J. Trump', 'Kamala Harris']

# Official Results
official_results = [57.94, 42.06]

# Predicted Results
predicted_results = [57.39, 42.61]

# Calculate Differences
differences = [predicted - official for predicted, official in zip(predicted_results, official_results)]

# Create a scatter plot
plt.figure(figsize=(8, 6))

# Plot Official Results
plt.scatter(candidates, official_results, color='g', label='Official Results', s=100, marker='o')
# Plot Predicted Results
plt.scatter(candidates, predicted_results, color='b', label='Predicted Results', s=100, marker='x')

# Add lines to show differences
for i in range(len(candidates)):
    plt.plot([candidates[i], candidates[i]], [official_results[i], predicted_results[i]], color='gray', linestyle='--')

# Add labels and title
plt.title('Comparison of Official and Predicted Results')
plt.xlabel('Candidates')
plt.ylabel('Percentage (%)')
plt.ylim(0, 100)  # Set y-axis limit for better visualization
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')  # Add a horizontal line at y=0
plt.grid()

# Add value labels on the points
for i, (official, predicted, diff) in enumerate(zip(official_results, predicted_results, differences)):
    plt.text(i, official + 1, f'Official: {official:.2f}%', ha='center', color='g')
    plt.text(i, predicted + 1, f'Predicted: {predicted:.2f}%', ha='center', color='b')
    plt.text(i, (official + predicted) / 2, f'Diff: {diff:.2f}%', ha='center', color='gray')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Ecuador Study

# %% [markdown]
# # Bar Chart Winner predictor results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the candidates
data = {
    "Candidate": [
        "Daniel Noboa", "Luisa Gonzales", "Andrea Gonzales", "Pedro Granja",
        "Francesco Tabacchi", "Leonidas Iza", "Carlos Rabascall", "Luis Tilleria",
        "Jimmy Jairala", "Henry Cucalon", "Ivan Saquicela", "Victor Arauz",
        "Jorge Escala", "Henry Kronfle", "Juan Cueva", "Wilson Gomez"
    ],
    "Value": [
          54.65,
        29.43,
        3.50,
        3.08,
        2.96,
        2.63,
        1.37,
        0.59,
        0.43,
        0.32,
        0.21,
        0.20,
        0.20,
        0.16,
        0.16,
        0.11
    ],
    "Percentage (%)": [
       54.65,
        29.43,
        3.50,
        3.08,
        2.96,
        2.63,
        1.37,
        0.59,
        0.43,
        0.32,
        0.21,
        0.20,
        0.20,
        0.16,
        0.16,
        0.11
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Define colors for each candidate
colors = [
    'purple',      # Daniel Noboa
    'skyblue',     # Luisa Gonzales
    'green',       # Andrea Gonzales
    'lightgray',   # Pedro Granja
    'lightgray',   # Francesco Tabacchi
    'brown',       # Leonidas Iza
    'lightgray',   # Carlos Rabascall
    'lightgray',   # Luis Tilleria
    'lightgray',   # Jimmy Jairala
    'lightgray',   # Henry Cucalon
    'lightgray',   # Ivan Saquicela
    'lightgray',   # Victor Arauz
    'lightgray',   # Jorge Escala
    'lightgray',   # Henry Kronfle
    'lightgray',   # Juan Cueva
    'lightgray'    # Wilson Gomez
]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['Candidate'], df['Value'], color=colors)
plt.xlabel('Candidates')
plt.ylabel('Value')
plt.title('Campaign Winner Predictor Election Results in Ecuador')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Data Frame campaign Winner predictor results

# %%
import pandas as pd

# Data
data = {
    "Candidate": [
        "Daniel Noboa",
        "Luisa Gonzales",
        "Andrea Gonzales",
        "Pedro Granja",
        "Francesco Tabacchi",
        "Leonidas Iza",
        "Carlos Rabascall",
        "Luis Tilleria",
        "Jimmy Jairala",
        "Henry Cucalon",
        "Ivan Saquicela",
        "Jorge Escala",
        "Victor Arauz",
        "Wilson Gomez",
        "Henry Kronfle",
        "Juan Cueva"
    ],
    "Percentage": [
        54.65,
        29.43,
        3.50,
        3.08,
        2.96,
        2.63,
        1.37,
        0.59,
        0.43,
        0.32,
        0.21,
        0.20,
        0.20,
        0.16,
        0.16,
        0.11
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## Campaign Winner Predictor results Ecuador "))

# Display the DataFrame
display(df)
# Out:
# ## Campaign Winner Predictor results Ecuador
#              Candidate  Percentage
# 0         Daniel Noboa       54.65
# 1       Luisa Gonzales       29.43
# 2      Andrea Gonzales        3.50
# 3         Pedro Granja        3.08
# 4   Francesco Tabacchi        2.96
# 5         Leonidas Iza        2.63
# 6     Carlos Rabascall        1.37
# 7        Luis Tilleria        0.59
# 8        Jimmy Jairala        0.43
# 9        Henry Cucalon        0.32
# 10      Ivan Saquicela        0.21
# 11        Jorge Escala        0.20
# 12        Victor Arauz        0.20
# 13        Wilson Gomez        0.16
# 14       Henry Kronfle        0.16
# 15          Juan Cueva        0.11

# %% [markdown]
# # Official Results CNE Bar Chart

# %%
import matplotlib.pyplot as plt

# Data
candidates = [
    "DANIEL NOBOA AZIN",
    "LUISA GONZALEZ",
    "LEONIDAS IZA",
    "ANDREA GONZALEZ",
    "HENRY KRONFLE KOZHAYA",
    "PEDRO GRANJA",
    "JIMMY JAIRALA VALLAZZA",
    "JORGE ESCALA",
    "HENRY CUCALON",
    "LUIS FELIPE TILLERIA",
    "FRANCESCO TABACCHI",
    "VICTOR ARAUS",
    "CARLOS RABASCALL",
    "WILSON GOMEZ",
    "JUAN IVAN CUEVA",
    "IVAN SAQUICELA"
]

percentages = [
    44.17,
    44.0,
    5.25,
    2.69,
    0.71,
    0.53,
    0.4,
    0.39,
    0.36,
    0.32,
    0.26,
    0.22,
    0.22,
    0.18,
    0.17,
    0.12
]

# Define colors for each candidate
colors = [
    'purple',      # Daniel Noboa
    'skyblue',     # Luisa Gonzalez
    'brown',         # Leonidas Iza
    'green',       # Andrea Gonzalez
    'lightgray',   # Other candidates
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray'
]

# Create vertical bar chart
plt.figure(figsize=(10, 6))
plt.bar(candidates, percentages, color=colors)
plt.ylabel('Percentage (%)')
plt.title('Official Results CNE')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.ylim(0, 50)  # Set y-axis limit for better visualization
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Frame Official results Ecuador

# %%
import pandas as pd

# Data
data = {
    "Candidate": [
        "DANIEL NOBOA AZIN",
        "LUISA GONZALEZ",
        "LEONIDAS IZA",
        "ANDREA GONZALEZ",
        "HENRY KRONFLE KOZHAYA",
        "PEDRO GRANJA",
        "JIMMY JAIRALA VALLAZZA",
        "JORGE ESCALA",
        "HENRY CUCALON",
        "LUIS FELIPE TILLERIA",
        "FRANCESCO TABACCHI",
        "VICTOR ARAUS",
        "CARLOS RABASCALL",
        "WILSON GOMEZ",
        "JUAN IVAN CUEVA",
        "IVAN SAQUICELA"
    ],
    "Percentage": [
        44.17,
        44.0,
        5.25,
        2.69,
        0.71,
        0.53,
        0.4,
        0.39,
        0.36,
        0.32,
        0.26,
        0.22,
        0.22,
        0.18,
        0.17,
        0.12
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## OFFICIAL Results Ecuador CNE "))

# Display the DataFrame
display(df)
# Out:
# ## OFFICIAL Results Ecuador CNE
#                  Candidate  Percentage
# 0        DANIEL NOBOA AZIN       44.17
# 1           LUISA GONZALEZ       44.00
# 2             LEONIDAS IZA        5.25
# 3          ANDREA GONZALEZ        2.69
# 4    HENRY KRONFLE KOZHAYA        0.71
# 5             PEDRO GRANJA        0.53
# 6   JIMMY JAIRALA VALLAZZA        0.40
# 7             JORGE ESCALA        0.39
# 8            HENRY CUCALON        0.36
# 9     LUIS FELIPE TILLERIA        0.32
# 10      FRANCESCO TABACCHI        0.26
# 11            VICTOR ARAUS        0.22
# 12        CARLOS RABASCALL        0.22
# 13            WILSON GOMEZ        0.18
# 14         JUAN IVAN CUEVA        0.17
# 15          IVAN SAQUICELA        0.12

# %% [markdown]
# # Chi Square test Ecuador

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create the data frames
predictor_data = {
    'Candidate': ['Daniel Noboa', 'Luisa Gonzales', 'Andrea Gonzales', 'Pedro Granja', 
                  'Francesco Tabacchi', 'Leonidas Iza', 'Carlos Rabascall', 'Luis Tilleria', 
                  'Jimmy Jairala', 'Henry Cucalon', 'Ivan Saquicela', 'Jorge Escala', 
                  'Victor Arauz', 'Wilson Gomez', 'Henry Kronfle', 'Juan Cueva'],
    'Percentage': [54.65, 29.43, 3.50, 3.08, 2.96, 2.63, 1.37, 0.59, 0.43, 0.32, 
                   0.21, 0.20, 0.20, 0.16, 0.16, 0.11]
}

official_data = {
    'Candidate': ['DANIEL NOBOA AZIN', 'LUISA GONZALEZ', 'LEONIDAS IZA', 
                  'ANDREA GONZALEZ', 'HENRY KRONFLE KOZHAYA', 'PEDRO GRANJA', 
                  'JIMMY JAIRALA VALLAZZA', 'JORGE ESCALA', 'HENRY CUCALON', 
                  'LUIS FELIPE TILLERIA', 'FRANCESCO TABACCHI', 'VICTOR ARAUS', 
                  'CARLOS RABASCALL', 'WILSON GOMEZ', 'JUAN IVAN CUEVA', 
                  'IVAN SAQUICELA'],
    'Percentage': [44.17, 44.00, 5.25, 2.69, 0.71, 0.53, 0.40, 0.39, 0.36, 
                   0.32, 0.26, 0.22, 0.22, 0.18, 0.17, 0.12]
}

df_predictor = pd.DataFrame(predictor_data)
df_official = pd.DataFrame(official_data)

# Normalize the percentages to counts (assuming total votes = 100 for simplicity)
total_votes = 100
df_predictor['Count'] = (df_predictor['Percentage'] / 100) * total_votes
df_official['Count'] = (df_official['Percentage'] / 100) * total_votes

# Merge the data frames on Candidate
merged_df = pd.merge(df_predictor, df_official, how='outer', on='Candidate', suffixes=('_predictor', '_official'))

# Fill NaN values with 0 for counts
merged_df.fillna(0, inplace=True)

# Create a contingency table
contingency_table = merged_df[['Count_predictor', 'Count_official']].values

# Run the Chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two distributions.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two distributions.")
# Out:
# Chi-square Statistic: 199.99
# P-value: 1.3024837086487455e-26
# Degrees of Freedom: 31
# Expected Frequencies:
# [[ 1.34506725  1.34493275]
#  [ 1.7500875   1.7499125 ]
#  [ 0.1100055   0.1099945 ]
#  [ 0.68503425  0.68496575]
#  [22.08610431 22.08389569]
#  [27.32636632 27.32363368]
#  [ 0.1300065   0.1299935 ]
#  [ 1.480074    1.479926  ]
#  [ 0.180009    0.179991  ]
#  [ 0.35501775  0.35498225]
#  [ 0.160008    0.159992  ]
#  [ 0.080004    0.079996  ]
#  [ 0.060003    0.059997  ]
#  [ 0.10500525  0.10499475]
#  [ 0.20001     0.19999   ]
#  [ 0.19500975  0.19499025]
#  [ 0.08500425  0.08499575]
#  [ 0.21501075  0.21498925]
#  [ 0.100005    0.099995  ]
#  [ 0.05500275  0.05499725]
#  [ 2.62513126  2.62486874]
#  [ 0.160008    0.159992  ]
#  [22.00110006 21.99889994]
#  [ 1.31506575  1.31493425]
#  [ 0.29501475  0.29498525]
#  [14.71573579 14.71426421]
#  [ 0.26501325  0.26498675]
#  [ 1.540077    1.539923  ]
#  [ 0.1100055   0.1099945 ]
#  [ 0.100005    0.099995  ]
# ...

# %% [markdown]
# # Ecuador Individual candidates Comparisson

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Daniel Noboa']

# Official Results
official_results = [44.17]

# Predicted Results
predicted_results = [54.65]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Daniel Noboa: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 60)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Luisa Gonzales']

# Official Results
official_results = [44.00]

# Predicted Results
predicted_results = [29.43]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Luisa Gonzales: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 60)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Leonidas Iza']

# Official Results
official_results = [5.25]

# Predicted Results
predicted_results = [2.63]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Leonidas Iza: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 10)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Andrea Gonzales']

# Official Results
official_results = [2.69]

# Predicted Results
predicted_results = [3.50]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Andrea Gonzales: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 5)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Henry Kronfle KOZHAYA']

# Official Results
official_results = [0.71]

# Predicted Results
predicted_results = [0.16]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Henry Kronfle KOZHAYA: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Pedro Granja']

# Official Results
official_results = [0.53]

# Predicted Results
predicted_results = [3.08]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Pedro Granja: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 4)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Jimmy Jairala Vallazza']

# Official Results
official_results = [0.40]

# Predicted Results
predicted_results = [0.43]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Jimmy Jairala Vallazza: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Jorge Escala']

# Official Results
official_results = [0.39]

# Predicted Results
predicted_results = [0.20]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Jorge Escala: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Henry Cucalon']

# Official Results
official_results = [0.36]

# Predicted Results
predicted_results = [0.32]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Henry Cucalon: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Luis Felipe Tilleria']

# Official Results
official_results = [0.32]

# Predicted Results
predicted_results = [0.59]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Luis Felipe Tilleria: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Francesco Tabacchi']

# Official Results
official_results = [0.26]

# Predicted Results
predicted_results = [2.96]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Francesco Tabacchi: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 3)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Victor Arauz']

# Official Results
official_results = [0.22]

# Predicted Results
predicted_results = [0.20]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Victor Arauz: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Carlos Rabascall']

# Official Results
official_results = [0.22]

# Predicted Results
predicted_results = [1.37]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Carlos Rabascall: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 2)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Wilson Gomez']

# Official Results
official_results = [0.18]  # Official result for Wilson Gomez

# Predicted Results
predicted_results = [0.16]  # Predicted result for Wilson Gomez

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Wilson Gomez: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Juan Ivan Cueva']

# Official Results
official_results = [0.17]  # Official result for Juan Ivan Cueva

# Predicted Results
predicted_results = [0.11]  # Predicted result for Juan Ivan Cueva

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Juan Ivan Cueva: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = ['Ivan Saquicela']

# Official Results
official_results = [0.12]  # Official result for Ivan Saquicela

# Predicted Results
predicted_results = [0.21]  # Predicted result for Ivan Saquicela

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (Blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Ivan Saquicela: Official vs Predicted Results')
ax.set_xticks(x)
ax.set_xticklabels(candidates)
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 1)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.show()

# %% [markdown]
# # Bar Chart Winner predictor and official results comparisson Ecuador

# %%
import matplotlib.pyplot as plt
import numpy as np

# Candidates
candidates = [
    'Daniel Noboa',
    'Luisa Gonzalez',
    'Leonidas Iza',
    'Andrea Gonzalez',
    'Henry Kronfle',
    'Pedro Granja',
    'Jimmy Jairala',
    'Jorge Escala',
    'Henry Cucalon',
    'Luis Felipe Tilleria',
    'Francesco Tabacchi',
    'Victor Arauz',
    'Carlos Rabascall',
    'Wilson Gomez',
    'Juan Ivan Cueva',
    'Ivan Saquicela'
]

# Official Results
official_results = [
    44.17,  # Daniel Noboa
    44.00,  # Luisa Gonzalez
    5.25,   # Leonidas Iza
    2.69,   # Andrea Gonzalez
    0.71,   # Henry Kronfle
    0.53,   # Pedro Granja
    0.40,   # Jimmy Jairala
    0.39,   # Jorge Escala
    0.36,   # Henry Cucalon
    0.32,   # Luis Felipe Tilleria
    0.26,   # Francesco Tabacchi
    0.22,   # Victor Arauz
    0.22,   # Carlos Rabascall
    0.18,   # Wilson Gomez
    0.17,   # Juan Ivan Cueva
    0.12    # Ivan Saquicela
]

# Predicted Results
predicted_results = [
    54.65,  # Daniel Noboa
    29.43,  # Luisa Gonzalez
    2.63,   # Leonidas Iza
    3.50,   # Andrea Gonzalez
    0.16,   # Henry Kronfle
    3.08,   # Pedro Granja
    0.43,   # Jimmy Jairala
    0.20,   # Jorge Escala
    0.32,   # Henry Cucalon
    0.59,   # Luis Felipe Tilleria
    2.96,   # Francesco Tabacchi
    0.20,   # Victor Arauz
    1.37,   # Carlos Rabascall
    0.16,   # Wilson Gomez
    0.11,   # Juan Ivan Cueva
    0.21    # Ivan Saquicela
]

# Create a bar chart
x = np.arange(len(candidates))  # the label locations
width = 0.4  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))  # Set figure size
bars1 = ax.bar(x - width/2, official_results, width, label='Official Results (blue)', color='blue')
bars2 = ax.bar(x + width/2, predicted_results, width, label='Predicted Results (Orange)', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage (%)')
ax.set_title('Comparison of Official vs Predicted Results for All Candidates')
ax.set_xticks(x)
ax.set_xticklabels(candidates, rotation=45, ha='right')  # Rotate candidate names for better visibility
ax.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

plt.ylim(0, 60)  # Set y-axis limit for better visualization
plt.grid(axis='y')  # Optional: Add grid lines for better readability

# Show the plot
plt.tight_layout()  # Adjust layout to make room for rotated x-axis labels
plt.show()

# %% [markdown]
# # Winner Predictor accuracy Data Frame

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': [
        'Daniel Noboa',
        'Luisa Gonzalez',
        'Leonidas Iza',
        'Andrea Gonzalez',
        'Henry Kronfle',
        'Pedro Granja',
        'Jimmy Jairala',
        'Jorge Escala',
        'Henry Cucalon',
        'Luis Felipe Tilleria',
        'Francesco Tabacchi',
        'Victor Arauz',
        'Carlos Rabascall',
        'Wilson Gomez',
        'Juan Ivan Cueva',
        'Ivan Saquicela'
    ],
    'Official Results (%)': [
        44.17,
        44.00,
        5.25,
        2.69,
        0.71,
        0.53,
        0.40,
        0.39,
        0.36,
        0.32,
        0.26,
        0.22,
        0.22,
        0.18,
        0.17,
        0.12
    ],
    'Predicted Results (%)': [
        54.65,
        29.43,
        2.63,
        3.50,
        0.16,
        3.08,
        0.43,
        0.20,
        0.32,
        0.59,
        2.96,
        0.20,
        1.37,
        0.16,
        0.11,
        0.21
    ],
    'Accuracy (%)': [
        '123.73%',
        '66.89%',
        '50.1%',
        '130.11%',
        '22.54%',
        '581.13%',
        '107.5%',
        '51.28%',
        '88.89%',
        '184.37%',
        '1138.46%',
        '90.91%',
        '622.73%',
        '88.89%',
        '64.71%',
        '175.0%'
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(data)

# Display the DataFrame
results_df
# Out:
#                Candidate  Official Results (%)  Predicted Results (%)  \
# 0           Daniel Noboa                 44.17                  54.65
# 1         Luisa Gonzalez                 44.00                  29.43
# 2           Leonidas Iza                  5.25                   2.63
# 3        Andrea Gonzalez                  2.69                   3.50
# 4          Henry Kronfle                  0.71                   0.16
# 5           Pedro Granja                  0.53                   3.08
# 6          Jimmy Jairala                  0.40                   0.43
# 7           Jorge Escala                  0.39                   0.20
# 8          Henry Cucalon                  0.36                   0.32
# 9   Luis Felipe Tilleria                  0.32                   0.59
# 10    Francesco Tabacchi                  0.26                   2.96
# 11          Victor Arauz                  0.22                   0.20
# ...

# %%
import pandas as pd
from tabulate import tabulate

# Data for the DataFrame
data = {
    'Candidate': [
        'Daniel Noboa',
        'Luisa Gonzalez',
        'Leonidas Iza',
        'Andrea Gonzalez',
        'Henry Kronfle',
        'Pedro Granja',
        'Jimmy Jairala',
        'Jorge Escala',
        'Henry Cucalon',
        'Luis Felipe Tilleria',
        'Francesco Tabacchi',
        'Victor Arauz',
        'Carlos Rabascall',
        'Wilson Gomez',
        'Juan Ivan Cueva',
        'Ivan Saquicela'
    ],
    'Official Results (%)': [
        44.17,
        44.00,
        5.25,
        2.69,
        0.71,
        0.53,
        0.40,
        0.39,
        0.36,
        0.32,
        0.26,
        0.22,
        0.22,
        0.18,
        0.17,
        0.12
    ],
    'Predicted Results (%)': [
        54.65,
        29.43,
        2.63,
        3.50,
        0.16,
        3.08,
        0.43,
        0.20,
        0.32,
        0.59,
        2.96,
        0.20,
        1.37,
        0.16,
        0.11,
        0.21
    ],
}

# Create the DataFrame
results_df = pd.DataFrame(data)

# Calculate the difference and format it
results_df['Difference (%)'] = results_df['Predicted Results (%)'] - results_df['Official Results (%)']
results_df['Difference (%)'] = results_df['Difference (%)'].apply(lambda x: f"{x:+.2f}%")  # Format with +/-

# Display the results in a table format
print(tabulate(results_df, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +----------------------+----------------------+-----------------------+----------------+
# |      Candidate       | Official Results (%) | Predicted Results (%) | Difference (%) |
# +----------------------+----------------------+-----------------------+----------------+
# |     Daniel Noboa     |        44.17         |         54.65         |    +10.48%     |
# |    Luisa Gonzalez    |         44.0         |         29.43         |    -14.57%     |
# |     Leonidas Iza     |         5.25         |         2.63          |     -2.62%     |
# |   Andrea Gonzalez    |         2.69         |          3.5          |     +0.81%     |
# |    Henry Kronfle     |         0.71         |         0.16          |     -0.55%     |
# |     Pedro Granja     |         0.53         |         3.08          |     +2.55%     |
# |    Jimmy Jairala     |         0.4          |         0.43          |     +0.03%     |
# ...

# %% [markdown]
# # Difference in Accuracy  Winner predictor results

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    "Candidate": [
        "Daniel Noboa", "Luisa Gonzalez", "Leonidas Iza", "Andrea Gonzalez",
        "Henry Kronfle", "Pedro Granja", "Jimmy Jairala", "Jorge Escala",
        "Henry Cucalon", "Luis Felipe Tilleria", "Francesco Tabacchi",
        "Victor Arauz", "Carlos Rabascall", "Wilson Gomez", "Juan Ivan Cueva",
        "Ivan Saquicela"
    ],
    "Official Results (%)": [
        44.17, 44.0, 5.25, 2.69, 0.71, 0.53, 0.4, 0.39, 0.36, 0.32,
        0.26, 0.22, 0.22, 0.18, 0.17, 0.12
    ],
    "Predicted Results (%)": [
        54.65, 29.43, 2.63, 3.5, 0.16, 3.08, 0.43, 0.2, 0.32, 0.59,
        2.96, 0.2, 1.37, 0.16, 0.11, 0.21
    ],
    "Difference (%)": [
        "+10.48%", "-14.57%", "-2.62%", "+0.81%", "-0.55%", "+2.55%",
        "+0.03%", "-0.19%", "-0.04%", "+0.27%", "+2.70%", "-0.02%",
        "+1.15%", "-0.02%", "-0.06%", "+0.09%"
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#                Candidate  Official Results (%)  Predicted Results (%)  \
# 0           Daniel Noboa                 44.17                  54.65
# 1         Luisa Gonzalez                 44.00                  29.43
# 2           Leonidas Iza                  5.25                   2.63
# 3        Andrea Gonzalez                  2.69                   3.50
# 4          Henry Kronfle                  0.71                   0.16
# 5           Pedro Granja                  0.53                   3.08
# 6          Jimmy Jairala                  0.40                   0.43
# 7           Jorge Escala                  0.39                   0.20
# 8          Henry Cucalon                  0.36                   0.32
# 9   Luis Felipe Tilleria                  0.32                   0.59
# 10    Francesco Tabacchi                  0.26                   2.96
# 11          Victor Arauz                  0.22                   0.20
# ...

# %% [markdown]
# # The Overall accuracy of the Ecuador model is 68.75%.

# %% [markdown]
# # Scatter Plot Ecuador Winner Predictor results

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
candidates = [
    "Daniel Noboa", "Luisa Gonzalez", "Leonidas Iza", "Andrea Gonzalez",
    "Henry Kronfle", "Pedro Granja", "Jimmy Jairala", "Jorge Escala",
    "Henry Cucalon", "Luis Felipe Tilleria", "Francesco Tabacchi",
    "Victor Arauz", "Carlos Rabascall", "Wilson Gomez", "Juan Ivan Cueva",
    "Ivan Saquicela"
]

official_results = [
    44.17, 44.00, 5.25, 2.69, 0.71, 0.53, 0.40, 0.39,
    0.36, 0.32, 0.26, 0.22, 0.22, 0.18, 0.17, 0.12
]

predicted_results = [
    54.65, 29.43, 2.63, 3.50, 0.16, 3.08, 0.43, 0.20,
    0.32, 0.59, 2.96, 0.20, 1.37, 0.16, 0.11, 0.21
]

# Create scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(official_results, predicted_results, color='blue', s=100, alpha=0.7, edgecolors='black')

# Add a trend line
z = np.polyfit(official_results, predicted_results, 1)
p = np.poly1d(z)
plt.plot(official_results, p(official_results), color='red', linestyle='--', linewidth=2, label='Trend Line')

# Annotate points
for i, candidate in enumerate(candidates):
    plt.annotate(candidate, (official_results[i], predicted_results[i]), fontsize=9, ha='right', 
                 bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'))

# Add labels and title
plt.title('Official vs Predicted Results', fontsize=16)
plt.xlabel('Official Results (%)', fontsize=14)
plt.ylabel('Predicted Results (%)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Set limits and ticks
plt.xlim(-5, 60)
plt.ylim(-5, 60)
plt.xticks(np.arange(0, 61, 5))
plt.yticks(np.arange(0, 61, 5))

# Add legend
plt.legend()

# Show plot
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.show()

# %% [markdown]
# # Accuracy Comparisson between USA and Ecuador

# %%
import pandas as pd

# Data
data = {
    'Metric': [
        'USA Accuracy Campaign Winner Predictor',
        'Overall Accuracy of Ecuador Model',
        'Difference between Models'
    ],
    'Percentage': [
        98.90,
        68.75,
        30.15
    ]
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#                                    Metric  Percentage
# 0  USA Accuracy Campaign Winner Predictor       98.90
# 1       Overall Accuracy of Ecuador Model       68.75
# 2               Difference between Models       30.15

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Define observed counts based on the assumed sample size
sample_size = 1000
observed_counts = np.array([[989, 11],  # USA Accuracy Campaign Winner
                            [688, 312]])  # Overall Accuracy of Ecuador Model

# Step 2: Create a contingency table
contingency_table = pd.DataFrame(observed_counts, 
                                  columns=['Success', 'Failure'], 
                                  index=['USA Accuracy', 'Ecuador Model'])

# Step 3: Perform Chi-Square test
chi2_stat, p_value, dof, expected_counts = chi2_contingency(contingency_table)

# Step 4: Output results
print("Chi-Square Statistic:", chi2_stat)
print("P-Value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Counts:\n", expected_counts)

# Step 5: Determine significance
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The discrepancies are statistically significant.")
else:
    print("Fail to reject the null hypothesis: The discrepancies are not statistically significant.")
# Out:
# Chi-Square Statistic: 332.30503386742134
# P-Value: 3.0251932095632403e-74
# Degrees of Freedom: 1
# Expected Counts:
#  [[838.5 161.5]
#  [838.5 161.5]]
# Reject the null hypothesis: The discrepancies are statistically significant.

# %%
import matplotlib.pyplot as plt

# Data (without the first bar)
labels = ['USA Accuracy Campaign', 'Ecuador Model Accuracy', 'Difference']
values = [98.90, 68.75, 30.15]

# Create bar chart
plt.figure(figsize=(10, 6))  # Optional: Set the figure size for better readability
bars = plt.bar(labels, values, color=['red', 'blue', 'green'])

# Add title and labels
plt.title('Model Accuracy Comparison', fontsize=16)
plt.ylabel('Percentage (%)', fontsize=14)
plt.ylim(0, 110)  # Set y-axis limit for better visualization

# Add data labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=12)

# Show the chart
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Optional: Add grid lines for better readability
plt.show()

# %% [markdown]
# # Study Social Networks Data Frame Supports

# %% [markdown]
# # Predictions were taken place aprox 3 days prior to elections

# %% [markdown]
# <h1>USA</h1>

# %% [markdown]
# # Instagram

# %%
import pandas as pd

# Data
data = {
    'Candidatos': ['Donald J Trump', 'Kamala Harris'],
    'Amount of Instagram Shares': [38530.00, 300084.00],
    'Percentage': [11.37, 88.63]
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#        Candidatos  Amount of Instagram Shares  Percentage
# 0  Donald J Trump                     38530.0       11.37
# 1   Kamala Harris                    300084.0       88.63

# %% [markdown]
# # Tik Tok

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidatos': ['Donald J Trump', 'Kamala Harris'],
    'Tik tok saves': [458400.00, 250845.00],
    'Percentage': ['64.66%', '35.34%']
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#        Candidatos  Tik tok saves Percentage
# 0  Donald J Trump       458400.0     64.66%
# 1   Kamala Harris       250845.0     35.34%

# %% [markdown]
# # Facebook

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidatos': ['Donald J Trump', 'Kamala Harris'],
    'Facebook Shares': [29625, 8474],
    'Percentage': [77.73, 22.27]
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#        Candidatos  Facebook Shares  Percentage
# 0  Donald J Trump            29625       77.73
# 1   Kamala Harris             8474       22.27

# %% [markdown]
# # Youtube

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': ['Donald J Trump', 'Kamala Harris'],
    'YouTube Likes': [1404800, 446959],
    'Percentage': [75.80, 24.20]
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#         Candidate  YouTube Likes  Percentage
# 0  Donald J Trump        1404800        75.8
# 1   Kamala Harris         446959        24.2

# %% [markdown]
# <h1>Ecuador</h1>

# %% [markdown]
# <h2>Instagram</h2>

# %%
import pandas as pd

# Data for the DataFrame
data = {
    "Candidates": [
        "Daniel Noboa",
        "Andrea Gonzales",
        "Francesco Tabacchi",
        "Luisa Gonzales",
        "Carlos Rabascall",
        "Pedro Granja",
        "Leonidas Iza",
        "Henry Cucalon",
        "Luis Tilleria",
        "Ivan Saquicela",
        "Henry Kronfle",
        "Jimmy Jairala",
        "Victor Arauz",
        "Jorge Escala",
        "Juan Cueva",
        "Wilson Gomez"
    ],
    "Amount of Instagram Shares": [
        22938.00,
        2500.00,
        1522.00,
        766.00,
        412.00,
        318.00,
        265.00,
        262.00,
        204.00,
        49.00,
        33.00,
        24.00,
        16.00,
        11.00,
        10.00,
        5.00
    ],
    "Percentage": [
        78.19,
        8.52,
        5.19,
        2.61,
        1.40,
        1.08,
        0.90,
        0.89,
        0.70,
        0.17,
        0.11,
        0.08,
        0.05,
        0.04,
        0.03,
        0.02
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#             Candidates  Amount of Instagram Shares  Percentage
# 0         Daniel Noboa                     22938.0       78.19
# 1      Andrea Gonzales                      2500.0        8.52
# 2   Francesco Tabacchi                      1522.0        5.19
# 3       Luisa Gonzales                       766.0        2.61
# 4     Carlos Rabascall                       412.0        1.40
# 5         Pedro Granja                       318.0        1.08
# 6         Leonidas Iza                       265.0        0.90
# 7        Henry Cucalon                       262.0        0.89
# 8        Luis Tilleria                       204.0        0.70
# 9       Ivan Saquicela                        49.0        0.17
# 10       Henry Kronfle                        33.0        0.11
# 11       Jimmy Jairala                        24.0        0.08
# 12        Victor Arauz                        16.0        0.05
# 13        Jorge Escala                        11.0        0.04
# ...

# %% [markdown]
# # Tik Tok

# %%
import pandas as pd

# Data for the DataFrame
data = {
    "Candidates": [
        "Daniel Noboa",
        "Luisa Gonzales",
        "Francesco Tabacchi",
        "Andrea Gonzales",
        "Pedro Granja",
        "Leonidas Iza",
        "Jimmy Jairala",
        "Luis Tilleria",
        "Ivan Saquicela",
        "Victor Arauz",
        "Henry Kronfle",
        "Carlos Rabascall",
        "Jorge Escala",
        "Wilson Gomez",
        "Henry Cucalon",
        "Juan Cueva"
    ],
    "Tik Tok Saves": [
        39640.00,
        12088.00,
        3771.00,
        1322.00,
        1001.00,
        496.00,
        411.00,
        313.00,
        305.00,
        281.00,
        215.00,
        162.00,
        77.00,
        58.00,
        44.00,
        28.00
    ],
    "Percentage": [
        65.83,
        20.08,
        6.26,
        2.20,
        1.66,
        0.82,
        0.68,
        0.52,
        0.51,
        0.47,
        0.36,
        0.27,
        0.13,
        0.10,
        0.07,
        0.05
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#             Candidates  Tik Tok Saves  Percentage
# 0         Daniel Noboa        39640.0       65.83
# 1       Luisa Gonzales        12088.0       20.08
# 2   Francesco Tabacchi         3771.0        6.26
# 3      Andrea Gonzales         1322.0        2.20
# 4         Pedro Granja         1001.0        1.66
# 5         Leonidas Iza          496.0        0.82
# 6        Jimmy Jairala          411.0        0.68
# 7        Luis Tilleria          313.0        0.52
# 8       Ivan Saquicela          305.0        0.51
# 9         Victor Arauz          281.0        0.47
# 10       Henry Kronfle          215.0        0.36
# 11    Carlos Rabascall          162.0        0.27
# 12        Jorge Escala           77.0        0.13
# 13        Wilson Gomez           58.0        0.10
# 14       Henry Cucalon           44.0        0.07
# 15          Juan Cueva           28.0        0.05

# %% [markdown]
# # Facebook

# %%
import pandas as pd

# Data
data = {
    "Candidatos": [
        "Daniel Noboa",
        "Luisa Gonzales",
        "Pedro Granja",
        "Leonidas Iza",
        "Andrea Gonzales",
        "Carlos Rabascall",
        "Jorge Escala",
        "Luis Tilleria",
        "Francesco Tabacchi",
        "Henry Cucalon",
        "Jimmy Jairala",
        "Juan Cueva",
        "Ivan Saquicela",
        "Henry Kronfle",
        "Victor Arauz",
        "Wilson Gomez"
    ],
    "Facebook Shares": [
        33675.00,
        33508.00,
        3197.00,
        2405.00,
        728.00,
        502.00,
        299.00,
        215.00,
        162.00,
        110.00,
        103.00,
        38.00,
        31.00,
        28.00,
        15.00,
        10.00
    ],
    "Percentage": [
        44.88,
        44.66,
        4.26,
        3.21,
        0.97,
        0.67,
        0.40,
        0.29,
        0.22,
        0.15,
        0.14,
        0.05,
        0.04,
        0.04,
        0.02,
        0.01
    ]
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#             Candidatos  Facebook Shares  Percentage
# 0         Daniel Noboa          33675.0       44.88
# 1       Luisa Gonzales          33508.0       44.66
# 2         Pedro Granja           3197.0        4.26
# 3         Leonidas Iza           2405.0        3.21
# 4      Andrea Gonzales            728.0        0.97
# 5     Carlos Rabascall            502.0        0.67
# 6         Jorge Escala            299.0        0.40
# 7        Luis Tilleria            215.0        0.29
# 8   Francesco Tabacchi            162.0        0.22
# 9        Henry Cucalon            110.0        0.15
# 10       Jimmy Jairala            103.0        0.14
# 11          Juan Cueva             38.0        0.05
# 12      Ivan Saquicela             31.0        0.04
# 13       Henry Kronfle             28.0        0.04
# 14        Victor Arauz             15.0        0.02
# 15        Wilson Gomez             10.0        0.01

# %% [markdown]
# # Yotube Likes

# %%
import pandas as pd

# Data
data = {
    "Candidates": [
        "Luisa Gonzales",
        "Daniel Noboa",
        "Leonidas Iza",
        "Pedro Granja",
        "Carlos Rabascall",
        "Andrea Gonzales",
        "Luis Tilleria",
        "Jimmy Jairala",
        "Wilson Gomez",
        "Juan Cueva",
        "Jorge Escala",
        "Victor Arauz",
        "Henry Cucalon",
        "Francesco Tabacchi",
        "Ivan Saquicela",
        "Henry Kronfle"
    ],
    "Number of likes": [
        6601.00,
        3892.00,
        732.00,
        698.00,
        411.00,
        302.00,
        111.00,
        107.00,
        68.00,
        39.00,
        33.00,
        32.00,
        24.00,
        22.00,
        18.00,
        17.00
    ],
    "Percentage": [
        50.36,
        29.69,
        5.58,
        5.33,
        3.14,
        2.30,
        0.85,
        0.82,
        0.52,
        0.30,
        0.25,
        0.24,
        0.18,
        0.17,
        0.14,
        0.13
    ]
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#             Candidatos  Number of likes  Percentage
# 0       Luisa Gonzales           6601.0       50.36
# 1         Daniel Noboa           3892.0       29.69
# 2         Leonidas Iza            732.0        5.58
# 3         Pedro Granja            698.0        5.33
# 4     Carlos Rabascall            411.0        3.14
# 5      Andrea Gonzales            302.0        2.30
# 6        Luis Tilleria            111.0        0.85
# 7        Jimmy Jairala            107.0        0.82
# 8         Wilson Gomez             68.0        0.52
# 9           Juan Cueva             39.0        0.30
# 10        Jorge Escala             33.0        0.25
# 11        Victor Arauz             32.0        0.24
# 12       Henry Cucalon             24.0        0.18
# 13  Francesco Tabacchi             22.0        0.17
# 14      Ivan Saquicela             18.0        0.14
# 15       Henry Kronfle             17.0        0.13

# %% [markdown]
# # Final Study Percentages Wrap up

# %% [markdown]
# # USA

# %%
import pandas as pd

# Data for the DataFrame
data = {
    "Candidate": ["Donald J Trump", "Kamala Harris", "Total"],
    "Instagram Shares J": [38530, 300084, 338614],
    "TikTok Saves U": [458400, 250845, 709245],
    "Facebook Shares G": [29625, 8474, 38099],
    "YouTube Likes Z": [1404800, 446959, 1851759],
    "Total Engagement XT": [1931355, 1006362, 2937717],
    "Percentage": [65.74, 34.26, 100.0]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
df
# Out:
#         Candidate  Instagram Shares J  TikTok Saves U  Facebook Shares G  \
# 0  Donald J Trump               38530          458400              29625
# 1   Kamala Harris              300084          250845               8474
# 2           Total              338614          709245              38099
#
#    YouTube Likes Z  Total Engagement XT  Percentage
# 0          1404800              1931355       65.74
# 1           446959              1006362       34.26
# 2          1851759              2937717      100.00
#         Candidate  Instagram Shares J  TikTok Saves U  Facebook Shares G  \
# 0  Donald J Trump               38530          458400              29625
# 1   Kamala Harris              300084          250845               8474
# 2           Total              338614          709245              38099
#
#    YouTube Likes Z  Total Engagement XT  Percentage
# 0          1404800              1931355       65.74
# 1           446959              1006362       34.26
# ...

# %% [markdown]
# # Ecuador

# %%
import pandas as pd

# Define the data
data = {
    "Candidate": [
        "Daniel Noboa", "Luisa Gonzales", "Andrea Gonzales", "Pedro Granja", 
        "Francesco Tabacchi", "Leonidas Iza", "Carlos Rabascall", "Luis Tilleria", 
        "Jimmy Jairala", "Henry Cucalon", "Ivan Saquicela", "Jorge Escala", 
        "Victor Arauz", "Wilson Gomez", "Henry Kronfle", "Juan Cueva"
    ],
    "Insta Shares J": [
        78.19, 2.61, 8.52, 1.08, 5.19, 0.90, 1.40, 0.70, 
        0.08, 0.89, 0.17, 0.04, 0.05, 0.02, 0.11, 0.03
    ],
    "Tik Tok Saves U": [
        65.83, 20.08, 2.20, 1.66, 6.26, 0.82, 0.27, 0.52, 
        0.68, 0.07, 0.51, 0.13, 0.47, 0.10, 0.36, 0.05
    ],
    "Facebook 10 last post shares G": [
        44.88, 44.66, 0.97, 4.26, 0.22, 3.21, 0.67, 0.29, 
        0.14, 0.15, 0.04, 0.40, 0.02, 0.01, 0.04, 0.05
    ],
    "youtube likes Z": [
        29.69, 50.36, 2.30, 5.33, 0.17, 5.58, 3.14, 0.85, 
        0.82, 0.18, 0.14, 0.25, 0.24, 0.52, 0.13, 0.30
    ],
    "total engagement XT": [
        218.61, 117.71, 13.99, 12.33, 11.83, 10.52, 5.48, 2.35, 
        1.72, 1.30, 0.85, 0.82, 0.79, 0.65, 0.64, 0.43
    ],
    "Percentage": [
        54.65, 29.43, 3.50, 3.08, 2.96, 2.63, 1.37, 0.59, 
        0.43, 0.32, 0.21, 0.20, 0.20, 0.16, 0.16, 0.11
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Normalize the "Insta Shares J" column to sum to 100
insta_shares_sum = df["Insta Shares J"].sum()
df["Insta Shares J"] = (df["Insta Shares J"] / insta_shares_sum) * 100

# Normalize the "Tik Tok Saves U" column to sum to 100
tik_tok_saves_sum = df["Tik Tok Saves U"].sum()
df["Tik Tok Saves U"] = (df["Tik Tok Saves U"] / tik_tok_saves_sum) * 100

# Normalize the "Facebook 10 last post shares G" column to sum to 100
facebook_shares_sum = df["Facebook 10 last post shares G"].sum()
df["Facebook 10 last post shares G"] = (df["Facebook 10 last post shares G"] / facebook_shares_sum) * 100

# Calculate the total row
total_row = pd.Series({
    "Candidate": "Total",
    "Insta Shares J": 100.00,  # Total Insta Shares J should be 100
    "Tik Tok Saves U": 100.00,  # Total Tik Tok Saves U should be 100
    "Facebook 10 last post shares G": 100.00,  # Total Facebook shares should be 100
    "youtube likes Z": df["youtube likes Z"].sum(),  # Sum of YouTube likes
    "total XT": 400.00,  # Total XT should be 400
    "Percentage": 100.00  # Total Percentage should be 100
})

# Append the total row while maintaining order
df = pd.concat([df, total_row.to_frame().T], ignore_index=True)

# Display the DataFrame
df
# Out:
#              Candidate Insta Shares J Tik Tok Saves U  \
# 0         Daniel Noboa      78.205641       65.823418
# 1       Luisa Gonzales       2.610522       20.077992
# 2      Andrea Gonzales       8.521704         2.19978
# 3         Pedro Granja       1.080216        1.659834
# 4   Francesco Tabacchi       5.191038        6.259374
# 5         Leonidas Iza        0.90018        0.819918
# 6     Carlos Rabascall        1.40028        0.269973
# 7        Luis Tilleria        0.70014        0.519948
# 8        Jimmy Jairala       0.080016        0.679932
# 9        Henry Cucalon       0.890178        0.069993
# 10      Ivan Saquicela       0.170034        0.509949
# 11        Jorge Escala       0.040008        0.129987
# 12        Victor Arauz        0.05001        0.469953
# 13        Wilson Gomez       0.020004         0.09999
# 14       Henry Kronfle       0.110022        0.359964
# 15          Juan Cueva       0.030006        0.049995
# ...

# %%
from IPython.display import display, HTML

html_content = """
<h2>Conclusion</h2>
<p>The analysis of predictive models and official results from both the U.S. and Ecuador elections reveals notable discrepancies, especially when the same algorithm was used in both countries. The impressive accuracy of the U.S. predictive model, with a deviation of only -0.55% for Trump and +0.55% for Harris, underscores the reliability of the electoral process in the U.S.</p>

<p>In contrast, the significant differences in Ecuador's results raise questions about the integrity of the electoral process there. Further investigation is warranted to substantiate claims of potential fraud.</p>

<p>While other companies expend millions on polls, our model has created a precise and diligent way to forecast electoral outcomes, saving future aspiring politicians and political marketing strategies millions.</p>
"""

display(HTML(html_content))
# Out:
# <h2>Conclusion</h2>
# <p>The analysis of predictive models and official results from both the U.S. and Ecuador elections reveals notable discrepancies, especially when the same algorithm was used in both countries. The impressive accuracy of the U.S. predictive model, with a deviation of only -0.55% for Trump and +0.55% for Harris, underscores the reliability of the electoral process in the U.S.</p>
#
# <p>In contrast, the significant differences in Ecuador's results raise questions about the integrity of the electoral process there. Further investigation is warranted to substantiate claims of potential fraud.</p>
#
# <p>While other companies expend millions on polls, our model has created a precise and diligent way to forecast electoral outcomes, saving future aspiring politicians and political marketing strategies millions.</p>
