# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the candidates
data = {
    "Candidate": [
        "Daniel Noboa", "Luisa Gonzales", "Andrea Gonzales", "Francesco Tabacchi",
        "Pedro Granja", "Leonidas Iza", "Jimmy Jairala", "Lus Tilleria",
        "Carlos Rabascall", "Victor Arauz", "Henry Kronfle", "Henry Cucalon",
        "Jorge Escala", "Ivan Saquicela", "Juan Cueva", "Wilson Gomez"
    ],
    "Value": [
        205.33, 109.59, 24.56, 13.6, 12.8, 9.81, 9.49, 3.13,
        3.11, 2.36, 1.88, 1.74, 1.18, 0.85, 0.31, 0.23
    ],
    "Percentage (%)": [
        51.38, 27.45, 6.15, 3.40, 3.20, 2.46, 2.37, 0.78,
        0.78, 0.59, 0.47, 0.44, 0.29, 0.21, 0.08, 0.06
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Define colors for each candidate
colors = [
    'purple',      # Daniel Noboa
    'skyblue',     # Luisa Gonzales
    'green',       # Andrea Gonzales
    'lightgray',   # Francesco Tabacchi
    'lightgray',   # Pedro Granja
    'brown',   # Leonidas Iza
    'lightgray',   # Jimmy Jairala
    'lightgray',   # Lus Tilleria
    'lightgray',   # Carlos Rabascall
    'lightgray',   # Victor Arauz
    'lightgray',   # Henry Kronfle
    'lightgray',   # Henry Cucalon
    'lightgray',   # Jorge Escala
    'lightgray',   # Ivan Saquicela
    'lightgray',   # Juan Cueva
    'lightgray'    # Wilson Gomez
]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['Candidate'], df['Value'], color=colors)
plt.xlabel('Candidates')
plt.ylabel('Value')
plt.title('Campaing winner predictor Election Results in Ecuador')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd

# Data for the candidates
data = {
    "Candidate": [
        "Daniel Noboa", "Luisa Gonzales", "Andrea Gonzales", "Francesco Tabacchi",
        "Pedro Granja", "Leonidas Iza", "Jimmy Jairala", "Lus Tilleria",
        "Carlos Rabascall", "Victor Arauz", "Henry Kronfle", "Henry Cucalon",
        "Jorge Escala", "Ivan Saquicela", "Juan Cueva", "Wilson Gomez"
    ],
    "Percentage (%)": [
        51.38, 27.45, 6.15, 3.40, 3.20, 2.46, 2.37, 0.78,
        0.78, 0.59, 0.47, 0.44, 0.29, 0.21, 0.08, 0.06
    ]
}

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## Ecuador Campaing Winner predictor election results"))

# Display the DataFrame
display(df)
# Out:
# ## Ecuador Campaing Winner predictor election results
#                  Candidate  Percentage
# 0        DANIEL NOBOA AZIN       44.17
# 1           LUISA GONZALEZ       44.00
# 2             LEONIDAS IZA        5.25
# 3          ANDREA GONZALEZ        2.69
# 4    HENRY KRONFLE KOZHAYA        0.71
# 5             PEDRO GRANJA        0.53
# 6   JIMMY JAIRALA VALLAZZA        0.40
# 7             JORGE ESCALA        0.39
# 8            HENRY CUCALON        0.36
# 9     LUIS FELIPE TILLERIA        0.32
# 10      FRANCESCO TABACCHI        0.26
# 11            VICTOR ARAUS        0.22
# 12        CARLOS RABASCALL        0.22
# 13           ENRIQUE GOMEZ        0.18
# 14         JUAN IVAN CUEVA        0.17
# 15          IVAN SAQUICELA        0.12

# %%
import matplotlib.pyplot as plt

# Data
candidates = [
    "DANIEL NOBOA AZIN",
    "LUISA GONZALEZ",
    "LEONIDAS IZA",
    "ANDREA GONZALEZ",
    "HENRY KRONFLE KOZHAYA",
    "PEDRO GRANJA",
    "JIMMY JAIRALA VALLAZZA",
    "JORGE ESCALA",
    "HENRY CUCALON",
    "LUIS FELIPE TILLERIA",
    "FRANCESCO TABACCHI",
    "VICTOR ARAUS",
    "CARLOS RABASCALL",
    "ENRIQUE GOMEZ",
    "JUAN IVAN CUEVA",
    "IVAN SAQUICELA"
]

percentages = [
    44.17,
    44.0,
    5.25,
    2.69,
    0.71,
    0.53,
    0.4,
    0.39,
    0.36,
    0.32,
    0.26,
    0.22,
    0.22,
    0.18,
    0.17,
    0.12
]

# Define colors for each candidate
colors = [
    'purple',      # Daniel Noboa
    'skyblue',     # Luisa Gonzalez
    'brown',         # Leonidas Iza
    'green',       # Andrea Gonzalez
    'lightgray',   # Other candidates
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray',
    'lightgray'
]

# Create vertical bar chart
plt.figure(figsize=(10, 6))
plt.bar(candidates, percentages, color=colors)
plt.ylabel('Percentage (%)')
plt.title('Aparently elections Fraude Results CNE')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.ylim(0, 50)  # Set y-axis limit for better visualization
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Data
data = {
    "Candidate": [
        "DANIEL NOBOA AZIN",
        "LUISA GONZALEZ",
        "LEONIDAS IZA",
        "ANDREA GONZALEZ",
        "HENRY KRONFLE KOZHAYA",
        "PEDRO GRANJA",
        "JIMMY JAIRALA VALLAZZA",
        "JORGE ESCALA",
        "HENRY CUCALON",
        "LUIS FELIPE TILLERIA",
        "FRANCESCO TABACCHI",
        "VICTOR ARAUS",
        "CARLOS RABASCALL",
        "ENRIQUE GOMEZ",
        "JUAN IVAN CUEVA",
        "IVAN SAQUICELA"
    ],
    "Percentage": [
        44.17,
        44.0,
        5.25,
        2.69,
        0.71,
        0.53,
        0.4,
        0.39,
        0.36,
        0.32,
        0.26,
        0.22,
        0.22,
        0.18,
        0.17,
        0.12
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## Apparently Election Results Fraud Ecuador CNE"))

# Display the DataFrame
display(df)
# Out:
# ## Apparently Election Results Fraud Ecuador CNE
#                  Candidate  Percentage
# 0        DANIEL NOBOA AZIN       44.17
# 1           LUISA GONZALEZ       44.00
# 2             LEONIDAS IZA        5.25
# 3          ANDREA GONZALEZ        2.69
# 4    HENRY KRONFLE KOZHAYA        0.71
# 5             PEDRO GRANJA        0.53
# 6   JIMMY JAIRALA VALLAZZA        0.40
# 7             JORGE ESCALA        0.39
# 8            HENRY CUCALON        0.36
# 9     LUIS FELIPE TILLERIA        0.32
# 10      FRANCESCO TABACCHI        0.26
# 11            VICTOR ARAUS        0.22
# 12        CARLOS RABASCALL        0.22
# 13           ENRIQUE GOMEZ        0.18
# 14         JUAN IVAN CUEVA        0.17
# 15          IVAN SAQUICELA        0.12

# %%
import matplotlib.pyplot as plt

# Data from your results
candidates = ['Donald J Trump', 'Kamala Harris']
percentages = [59.25, 40.75]  # Percentages

# Create a vertical bar chart
plt.bar(candidates, percentages, color=['red', 'blue'])

# Add title and labels
plt.title('USA Campaing winner predictor results')
plt.xlabel('Candidates')
plt.ylabel('Percentage (%)')

# Set y-axis limits for better visualization
plt.ylim(0, 100)

# Show the chart
plt.show()

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': ['Donald J Trump', 'Kamala Harris'],
    'Percentage (%)': [59.25, 40.75]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## USA Campaing winner predictor results"))

# Display the DataFrame
display(df)
# Out:
# ## USA Campaing winner predictor results
#         Candidate  Percentage (%)
# 0  Donald J Trump           59.25
# 1   Kamala Harris           40.75

# %%
import matplotlib.pyplot as plt

# Data from your results
candidates = ['Donald J Trump', 'Kamala Harris']
percentages = [57.94, 42.06]  # Percentages

# Create a vertical bar chart
plt.bar(candidates, percentages, color=['red', 'blue'])

# Add title and labels
plt.title('USA Official results')
plt.xlabel('Candidates')
plt.ylabel('Percentage (%)')

# Set y-axis limits for better visualization
plt.ylim(0, 100)

# Show the chart
plt.show()

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Candidate': ['Donald J Trump', 'Kamala Harris'],
    'Percentage (%)': [57.94, 42.06]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display H2 title
from IPython.display import display, Markdown
display(Markdown("## USA official results"))

# Display the DataFrame
display(df)
# Out:
# ## USA official results
#         Candidate  Percentage (%)
# 0  Donald J Trump           57.94
# 1   Kamala Harris           42.06
