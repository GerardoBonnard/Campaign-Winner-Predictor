# %% [markdown]
# # Estudio realizado el 24 de Marzo del 2025 un día después del debate presidencial

# %%
import pandas as pd

# Data for Instagram Shares
instagram_data = {
    "Category": ["Instagram Shares", "Instagram Shares", "Total"],
    "Candidates": ["Daniel Noboa", "Luisa González", ""],
    "Amount": [18060.00, 436.00, 18496.00],
    "Percentage": [97.64, 2.36, 100.00]
}

# Data for Tik Tok Saves
tiktok_data = {
    "Category": ["Tik Tok Saves", "Tik Tok Saves", "Total"],
    "Candidates": ["Daniel Noboa", "Luisa González", ""],
    "Amount": [28068.00, 20918.00, 48986.00],
    "Percentage": [57.30, 42.70, 100.00]
}

# Data for Facebook Shares
facebook_data = {
    "Category": ["Facebook Shares", "Facebook Shares", "Total"],
    "Candidates": ["Daniel Noboa", "Luisa González", ""],
    "Amount": [41310.00, 14799.00, 56109.00],
    "Percentage": [73.62, 26.38, 100.00]
}

# Data for Youtube Likes
youtube_data = {
    "Category": ["Youtube Likes", "Youtube Likes", "Total"],
    "Candidates": ["Luisa González", "Daniel Noboa", ""],
    "Amount": [53.00, 37.00, 90.00],
    "Percentage": [58.89, 41.11, 100.00]
}

# Creating DataFrames
df_instagram = pd.DataFrame(instagram_data)
df_tiktok = pd.DataFrame(tiktok_data)
df_facebook = pd.DataFrame(facebook_data)
df_youtube = pd.DataFrame(youtube_data)

# Concatenating all DataFrames
df_combined = pd.concat([df_instagram, df_tiktok, df_facebook, df_youtube], ignore_index=True)

# Displaying the combined DataFrame
df_combined
# Out:
#             Category      Candidates   Amount  Percentage
# 0   Instagram Shares    Daniel Noboa  18060.0       97.64
# 1   Instagram Shares  Luisa González    436.0        2.36
# 2              Total                  18496.0      100.00
# 3      Tik Tok Saves    Daniel Noboa  28068.0       57.30
# 4      Tik Tok Saves  Luisa González  20918.0       42.70
# 5              Total                  48986.0      100.00
# 6    Facebook Shares    Daniel Noboa  41310.0       73.62
# 7    Facebook Shares  Luisa González  14799.0       26.38
# 8              Total                  56109.0      100.00
# 9      Youtube Likes  Luisa González     53.0       58.89
# 10     Youtube Likes    Daniel Noboa     37.0       41.11
# 11             Total                     90.0      100.00

# %%
import matplotlib.pyplot as plt

# Data
candidates = ['Daniel Noboa', 'Luisa González']
percentages = [67.42, 32.58]

# Create bar chart
plt.figure(figsize=(8, 5))  # Set the figure size
bars = plt.bar(candidates, percentages, color=['#6A0DAD', '#1E90FF'], edgecolor='black')

# Add title and labels
plt.title('Predicciones Electorales Ecuador 13 de Abril 2025', fontsize=16, fontweight='bold')
plt.xlabel('Candidatos', fontsize=14)
plt.ylabel('Porcentaje (%)', fontsize=14)

# Add percentage labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=12)

# Show grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set y-axis limit
plt.ylim(0, 100)

# Show the chart
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()
